# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("flights.zip", sep="|")

# %%
df.head(30)
# Out:
#     TRANSACTIONID  FLIGHTDATE AIRLINECODE  \
# 0        54548800    20020101          WN
# 1        55872300    20020101          CO
# 2        54388800    20020101          WN
# 3        54486500    20020101          WN
# 4        55878700    20020103          CO
# 5        54380600    20020103          WN
# 6        55117600    20020104          DL
# 7        55232700    20020105          DL
# 8        54624700    20020105          WN
# 9        54613800    20020105          WN
# 10       54583300    20020105          WN
# 11       54428000    20020106          WN
# 12       54527000    20020106          WN
# 13       54401600    20020107          WN
# 14       54642900    20020108          WN
# 15       54660500    20020108          WN
# 16       55964000    20020108          CO
# 17       55404900    20020108          HP
# 18       54355400    20020110          WN
# 19       54495500    20020110          WN
# 20       55755400    20020110          AA
# 21       54434700    20020110          WN
# 22       54486100    20020111          WN
# 23       54496500    20020111          WN
# 24       54568500    20020111          WN
# 25       55405400    20020111          HP
# 26       54511100    20020111          WN
# 27       54396400    20020116          WN
# 28       54519900    20020116          WN
# 29       54865900    20020117          UA
#
#                                           AIRLINENAME TAILNUM  FLIGHTNUM  \
# 0                          Southwest Airlines Co.: WN  N103@@       1425
# 1                      Continental Air Lines Inc.: CO  N83872        150
# 2                          Southwest Airlines Co.: WN  N334@@        249
# 3                          Southwest Airlines Co.: WN  N699@@        902
# 4                      Continental Air Lines Inc.: CO  N58606        234
# 5                          Southwest Airlines Co.: WN  N501@@        193
# 6                            Delta Air Lines Inc.: DL  N37574        262
# 7                            Delta Air Lines Inc.: DL  N517D1       1214
# 8                          Southwest Airlines Co.: WN  N679@@       2122
# 9                          Southwest Airlines Co.: WN  N791@@       2038
# 10                         Southwest Airlines Co.: WN  N662@@       1737
# 11                         Southwest Airlines Co.: WN  N330@@        502
# 12                         Southwest Airlines Co.: WN  N328@@       1258
# 13                         Southwest Airlines Co.: WN  N507@@        334
# 14                         Southwest Airlines Co.: WN  N773@@       2312
# 15                         Southwest Airlines Co.: WN  N602@@       2734
# 16                     Continental Air Lines Inc.: CO  N17326       1769
# 17  America West Airlines Inc.: HP (Merged with US...   N316A        763
# 18                         Southwest Airlines Co.: WN  N87@@@         57
# 19                         Southwest Airlines Co.: WN  N326@@        962
# 20                         American Airlines Inc.: AA   N4HA1       2654
# 21                         Southwest Airlines Co.: WN  N745@@        535
# 22                         Southwest Airlines Co.: WN  N695@@        900
# 23                         Southwest Airlines Co.: WN  N331@@        971
# 24                         Southwest Airlines Co.: WN  N313@@       1609
# 25  America West Airlines Inc.: HP (Merged with US...   N168A        767
# 26                         Southwest Airlines Co.: WN  N644@@       1118
# 27                         Southwest Airlines Co.: WN  N361@@        301
# 28                         Southwest Airlines Co.: WN  N634@@       1190
# 29                          United Air Lines Inc.: UA   N9361        258
#
#    ORIGINAIRPORTCODE                                   ORIGAIRPORTNAME  \
# 0                ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 1                ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 2                ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 3                ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 4                ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 5                ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 6                ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 7                ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 8                ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 9                ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 10               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 11               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 12               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 13               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 14               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 15               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 16               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 17               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 18               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 19               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 20               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 21               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 22               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 23               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 24               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 25               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 26               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 27               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 28               ABQ  AlbuquerqueNM: Albuquerque International Sunport
# 29               ABQ  AlbuquerqueNM: Albuquerque International Sunport
#
#    ORIGINCITYNAME ORIGINSTATE  ... WHEELSON TAXIIN CRSARRTIME ARRTIME  \
# 0     Albuquerque          NM  ...   1648.0    4.0       1655  1652.0
# 1     Albuquerque          NM  ...   1419.0   16.0       1426  1435.0
# 2     Albuquerque          NM  ...   1618.0    2.0       1500  1620.0
# 3     Albuquerque          NM  ...   1947.0    1.0       1950  1948.0
# 4     Albuquerque          NM  ...   1742.0    5.0       1750  1747.0
# 5     Albuquerque          NM  ...   1822.0    4.0       1805  1826.0
# 6     Albuquerque          NM  ...   2043.0   12.0       1807  2055.0
# 7     Albuquerque          NM  ...   1957.0    6.0       1812  2003.0
# 8     Albuquerque          NM  ...   1925.0    5.0       1840  1930.0
# 9     Albuquerque          NM  ...   1108.0    7.0       1050  1115.0
# 10    Albuquerque          NM  ...   1008.0    2.0       1010  1010.0
# 11    Albuquerque          NM  ...   1053.0    2.0       1055  1055.0
# 12    Albuquerque          NM  ...   1554.0    1.0       1555  1555.0
# 13    Albuquerque          NM  ...   2023.0    4.0       2035  2027.0
# 14    Albuquerque          NM  ...   1339.0    2.0       1355  1341.0
# 15    Albuquerque          NM  ...    857.0    3.0        905   900.0
# 16    Albuquerque          NM  ...    953.0    6.0       1001   959.0
# 17    Albuquerque          NM  ...    730.0    4.0        753   734.0
# 18    Albuquerque          NM  ...   1905.0    2.0       1850  1907.0
# 19    Albuquerque          NM  ...   1616.0    4.0       1545  1620.0
# 20    Albuquerque          NM  ...   1739.0   13.0       1732  1752.0
# 21    Albuquerque          NM  ...   1448.0    4.0       1455  1452.0
# 22    Albuquerque          NM  ...   1352.0    4.0       1400  1356.0
# 23    Albuquerque          NM  ...   2002.0    6.0       2010  2008.0
# 24    Albuquerque          NM  ...    812.0    3.0        830   815.0
# 25    Albuquerque          NM  ...   1311.0    5.0       1342  1316.0
# 26    Albuquerque          NM  ...   1201.0    4.0       1210  1205.0
# 27    Albuquerque          NM  ...    702.0    3.0        705   705.0
# 28    Albuquerque          NM  ...   2235.0    5.0       2240  2240.0
# 29    Albuquerque          NM  ...   1457.0    4.0       1515  1501.0
#
#    ARRDELAY CRSELAPSEDTIME  ACTUALELAPSEDTIME  CANCELLED  DIVERTED    DISTANCE
# 0      -3.0           90.0               87.0          F     False   580 miles
# 1       9.0          116.0              119.0      False         F   744 miles
# 2      80.0          105.0              102.0          F     False   718 miles
# 3      -2.0           85.0               83.0          0         0   487 miles
# 4      -3.0          115.0              114.0          F     False   744 miles
# 5      21.0           55.0               49.0      False         F   289 miles
# 6     168.0           97.0               98.0      False     False   569 miles
# 7     111.0          157.0              163.0          F     False  1240 miles
# 8      50.0           50.0               40.0      False         F   223 miles
# 9      25.0          125.0              115.0          F     False   677 miles
# 10      0.0           75.0               68.0          F     False   328 miles
# 11      0.0           90.0               82.0          F     False   580 miles
# 12      0.0          105.0               93.0      False         F   628 miles
# 13     -8.0           90.0               82.0          0         0   487 miles
# 14    -14.0          170.0              156.0          F     False  1121 miles
# 15     -5.0           95.0               90.0      False     False   580 miles
# 16     -2.0          121.0              125.0      False         F   744 miles
# 17    -19.0           85.0               69.0      False         F   328 miles
# 18     17.0           55.0               52.0          0         0   277 miles
# 19     35.0           60.0               95.0          0         0   332 miles
# 20     20.0          136.0              160.0      False     False   934 miles
# 21     -3.0          135.0              132.0      False     False   934 miles
# 22     -4.0           55.0               51.0          0         0   277 miles
# 23     -2.0          150.0              138.0      False         F   889 miles
# 24    -15.0           75.0               60.0          0         0   328 miles
# 25    -26.0           87.0               65.0          F     False   328 miles
# 26     -5.0           75.0               70.0          0         0   328 miles
# 27      0.0           90.0               90.0          0         0   487 miles
# 28      0.0           75.0               75.0          0         0   328 miles
# 29    -14.0           75.0               63.0      False         F   349 miles
#
# [30 rows x 31 columns]

# %%
#Igualar el tipo de dato en la columna CANCELLED
df.CANCELLED.replace({"False": 0, "F": 0, "0": 0}, inplace = True)
df.CANCELLED.replace({"True": 1, "T": 1, "1": 1}, inplace = True)
df.CANCELLED.dtype
# Out:
# dtype('int64')

# %%
#Igualar el tipo de dato en la columna DIVERTED
df.DIVERTED.replace({"False": 0, "F": 0, "0": 0}, inplace = True)
df.DIVERTED.replace({"True": 1, "T": 1, "1": 1}, inplace = True)
df.CANCELLED.dtype
# Out:
# dtype('int64')

# %%
#X = df.iloc[:,1:]

# %%
#sc = StandardScaler()

# %%
#sc.fit(X)

# %%
#X_norm = sc.transform(X)

# %%
#X_norm

# %%
#X_norm.shape

# %%
#clusters = np.arange(2,10)

# %%
#clusters

# %%
#inercias = []
#for k in clusters:
#    kmeans = KMeans(n_clusters=k, random_state=0)
#    kmeans.fit(X_norm)
#    inercias.append(kmeans.inertia_)

# %%
#eva = pd.DataFrame({"K":clusters, "inercia":inercias})

# %%
#eva

# %%
#fig, ax = plt.subplots(figsize=(10,8))
#sns.lineplot(data = eva, x = "K", y = "inercia")

# %%
#kmeans = KMeans(n_clusters=4, random_state=0)

# %%
#kmeans.fit(X_norm)

# %%
#kmeans.cluster_centers_

# %%
#df["cluster"] = kmeans.labels_

# %%
#df.head()

# %%
#sns.pairplot(df,hue="cluster", palette="tab10")

# %%
#df.loc[df["cluster"]==3]

# %%
#sns.boxplot(x="cluster", y="Murder", data=df)

# %%
#sns.boxplot(x="cluster", y="Rape", data=df)
